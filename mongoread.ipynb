# %%
import random,logging
import pymongo
from pymongo import MongoClient
import logging

def emp_data():
    l=[]
    for i in range(20):
        d={"emp_id":i, "department":random.choice(['IT','HR','Sales','Operations']),
          "salary":random.randint(10000,100000),"working_mode":random.choice(['Hybrid','onsite'])}
        logging.info(d)
        l.append(d)
    return l


def write(l):
    client = pymongo.MongoClient("mongodb://chetan_user:chetan123@db.stg.bdb.ai:27017/?authMechanism=DEFAULT&authSource=pipeline&directConnection=true")
    db = client["pipeline"] 
    collection = db["emp_data"]  
    collection.insert_many(l)

    
def start():
    l=emp_data()
    logging.info("=============================Employee data read===============================")
    w=write(l)
    logging.info("=============================Data Written=====================================") 
    return ["Data Read and written successfully."]

# %%
from python_files import s3_test
import logging
def fun1():
    logging.info("=========Utills has been read==============")
    res=s3_test.read_s3()
    return res

# %%
fun1()
# Out:
#                                    source_id system_conversation_id conversation_id  org_id  cust_id  agent_id  business_unit_id conversation_date conversation_type cust_client_id agent_client_id  journey_id conversation_timestamp   duration  duration_slab_id         duration_slab_name   duration_slab_range  hold_count hold_duration  hold_percentage  agent_speech_overlap_count  agent_speech_overlap_duration  cust_speech_overlap_count  cust_speech_overlap_duration  agent_long_talk_count  agent_long_talk_duration  cust_long_talk_count  cust_long_talk_duration    created_timestamp
# ...

# %%
from python_files import files
import boto3
import pandas as pd
from io import BytesIO
import pymongo
from pymongo import MongoClient
def fun2():
    aws_access_key_id = 'AKIAWDC5PDRIGMLYN45H'
    aws_secret_access_key = '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'
    bucket_name = 'sandeep0924'
    prefix = 'jobs/'
    conn_str='mongodb://chetan_user:chetan123@db.stg.bdb.ai:27017/?authMechanism=DEFAULT&authSource=pipeline&directConnection=true'
    database='pipeline'
    collection='python_ondemandjob'
    res=files.read_s3_data(aws_access_key_id=aws_access_key_id,aws_secret_access_key=aws_secret_access_key,bucket_name=bucket_name,prefix=prefix,conn_str=conn_str,database=database,collection=collection)
    return res

# %%
# aws_access_key_id = 'AKIAWDC5PDRIGMLYN45H'
# aws_secret_access_key = '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'
# bucket_name = 'sandeep0924'
# prefix = 'jobs/'
# conn_str='mongodb://chetan_user:chetan123@db.stg.bdb.ai:27017/?authMechanism=DEFAULT&authSource=pipeline&directConnection=true'
# database='pipeline'
# collection='python_ondemandjob'

fun2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 9
#       1 # aws_access_key_id = 'AKIAWDC5PDRIGMLYN45H'
#       2 # aws_secret_access_key = '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'
#       3 # bucket_name = 'sandeep0924'
#    (...)
#       6 # database='pipeline'
#       7 # collection='python_ondemandjob'
# ----> 9 fun2()
#
# Cell In[55], line 15, in fun2()
#      13 database='pipeline'
#      14 collection='python_ondemandjob'
# ---> 15 res=files.read_s3_data(aws_access_key_id=aws_access_key_id,aws_secret_access_key=aws_secret_access_key,bucket_name=bucket_name,prefix=prefix,conn_str=conn_str,database=database,collection=collection)
#      16 return res
#
# File @SYS.DATASANDBOX_PATH/129204231/Repo/python_files/files.py:7, in read_s3_data(aws_access_key_id, aws_secret_access_key, bucket_name, prefix, conn_str, database, collection)
# ...

# %%
from python_files.s3_bucket_files import s3_files
from pymongo import MongoClient
import logging
def read(aws_access_key_id,aws_secret_access_key,bucket_name,prefix,conn_str,database,collection):
    val=s3_files.read_s3_data(aws_access_key_id=aws_access_key_id,aws_secret_access_key=aws_secret_access_key,bucket_name=bucket_name,prefix=prefix,conn_str=conn_str,database=database,collection=collection)
    return val

# %%
from python_files.s3_bucket_files import s3_files
s3_files.read_s3_data()

# %%
from python_files.s3_bucket_files import s3_files
print(dir(s3_files))
# Out:
# ['BytesIO', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'boto3', 'funs', 'pd', 'read_s3_data']

# %%
# %%bash
# pip install pymongo

# %%
import pymongo

# %%
aws_access_key_id = 'AKIAWDC5PDRIGMLYN45H'
aws_secret_access_key = '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'
bucket_name = 'sandeep0924'
prefix = 'jobs/'
conn_str='mongodb://chetan_user:chetan123@db.stg.bdb.ai:27017/?authMechanism=DEFAULT&authSource=pipeline&directConnection=true'
database='pipeline'
collection='python_ondemandjob'

read(aws_access_key_id,aws_secret_access_key,bucket_name,prefix,conn_str,database,collection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       6 database='pipeline'
#       7 collection='python_ondemandjob'
# ----> 9 read(aws_access_key_id,aws_secret_access_key,bucket_name,prefix,conn_str,database,collection)
#
# Cell In[6], line 5, in read(aws_access_key_id, aws_secret_access_key, bucket_name, prefix, conn_str, database, collection)
#       4 def read(aws_access_key_id,aws_secret_access_key,bucket_name,prefix,conn_str,database,collection):
# ----> 5     val=s3_files.read_s3_data(aws_access_key_id=aws_access_key_id,aws_secret_access_key=aws_secret_access_key,bucket_name=bucket_name,prefix=prefix,conn_str=conn_str,database=database,collection=collection)
#       6     return val
#
# ...

# %%
start()

# %%
import paramiko

# Define SFTP connection parameters
hostname = 'your_sftp_hostname'
port = 22  # Default SFTP port is 22
username = 'your_username'
password = 'your_password'

# Initialize an SSH client
ssh_client = paramiko.SSHClient()
ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())

# Connect to the SFTP server
ssh_client.connect(hostname=hostname, port=port, username=username, password=password)

# Open an SFTP session
sftp_client = ssh_client.open_sftp()

# Define the remote directory path you want to list files from
remote_directory_path = '/path/to/remote/directory'  # Replace with your directory path

# Change to the remote directory
sftp_client.chdir(remote_directory_path)

# List all files in the remote directory
file_list = sftp_client.listdir()

# Print the list of files
print("List of files in the remote directory:")
for file_name in file_list:
    print(file_name)

# Close the SFTP session and SSH connection
sftp_client.close()
ssh_client.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import paramiko
#       3 # Define SFTP connection parameters
#       4 hostname = 'your_sftp_hostname'
#
# ModuleNotFoundError: No module named 'paramiko'

# %%
# read()

# %%
import paramiko


def read_sftp(hostname,port,username,password):
    ssh_client = paramiko.SSHClient()
    ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh_client.connect(hostname=hostname, port=port, username=username, password=password)
    sftp_client = ssh_client.open_sftp()
    remote_directory_path = '/home/shabnam/source'  
    sftp_client.chdir(remote_directory_path)
    file_list = sftp_client.listdir()

    # Print the list of files
    print("List of files in the remote directory:")
    for file_name in file_list:
        logging.info(file_name)
        print(file_name)

    sftp_client.close()
    ssh_client.close()

# %%
read_sftp('172.21.85.186',22,'shabnam','Sh173$2763!')

# %%
from python_files import add
def sum(a,b,c):
    res=add.start(a,b,c)
    return res

# %%
a=2
b=3
c=5
sum(a,b,c)
# Out:
# 10

# %%
import boto3
import pandas as pd
from io import BytesIO
import pymongo
from pymongo import MongoClient



def read_s3_data(aws_access_key_id,aws_secret_access_key,bucket_name,prefix,conn_str,database,collection):
    client = MongoClient(conn_str)
    db = client[database] 
    collection = db[collection]
    s3_client = boto3.client('s3', aws_access_key_id=aws_access_key_id,
                            aws_secret_access_key=aws_secret_access_key)


    objects = s3_client.list_objects(Bucket=bucket_name, Prefix=prefix)


    for obj in objects.get('Contents', []):
        file_key = obj['Key']


        if not file_key.endswith('/'):

            response = s3_client.get_object(Bucket=bucket_name, Key=file_key)
            file_content = response['Body'].read()


            df = pd.read_csv(BytesIO(file_content))
            records = df.to_dict(orient='records')
            
            collection.insert_many(records)
            print(f"Inserted {df.shape[0]} rows  into MongoDB")
            logging.info(f"Inserted {df.shape[0]} rows  into MongoDB")

            print(f"File: {file_key}, Shape: {df.shape}")
            logging.info(f"File: {file_key}, Shape: {df.shape}")
            
def funs():
    return "Yes"

# %%
aws_access_key_id = 'AKIAWDC5PDRIGMLYN45H'
aws_secret_access_key = '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'
bucket_name = 'sandeep0924'
prefix = 'jobs/'
conn_str='mongodb://chetan_user:chetan123@db.stg.bdb.ai:27017/?authMechanism=DEFAULT&authSource=pipeline&directConnection=true'
database='pipeline'
collection='python_ondemandjob'

read_s3_data(aws_access_key_id,aws_secret_access_key,bucket_name,prefix,conn_str,database,collection)
# Out:
# Inserted 312 rows  into MongoDB
# File: jobs/ApportionedIdentifiers.csv, Shape: (312, 15)
# Inserted 1000 rows  into MongoDB
# File: jobs/accounts.csv, Shape: (1000, 16)
# Inserted 5498 rows  into MongoDB
# File: jobs/census_2011.csv, Shape: (5498, 33)
# Inserted 100 rows  into MongoDB
# File: jobs/emp.csv, Shape: (100, 11)
# Inserted 10 rows  into MongoDB
# File: jobs/s3_test.csv, Shape: (10, 12)
# Inserted 50000 rows  into MongoDB
# File: jobs/small_table_202401192033.csv, Shape: (50000, 5)
